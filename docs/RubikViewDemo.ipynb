# %%
# You need to install IJulia and either ImageIO or ImageMagick to show images.
using RubikCore, RubikView

# %%
c = rand(Cube)
# Out:
# 3x3x3 Cube:
#           B  L  R
#           L  L  D
#           L  B  U
#  R  U  B  D  L  B  L  R  D  B  F  U
#  B  F  F  U  U  B  U  B  L  D  D  R
#  L  U  F  R  F  F  D  B  F  U  F  F
#           D  D  L
#           R  R  D
#           U  R  R

# %%
RubikView.draw_net(c)
# Out:
# 264×354 Array{ARGB32,2} with eltype ColorTypes.ARGB32:
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
# ...

# %%
RubikView.draw_flat_net(c)
# Out:
# 300×390 Array{ARGB32,2} with eltype ColorTypes.ARGB32:
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
# ...

# %%
RubikView.draw_oblique_net(c, attach_left = :up, attach_back = :up, attach_down = :right)
# Out:
# 354×264 Array{ARGB32,2} with eltype ColorTypes.ARGB32:
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
# ...

# %%
RubikView.draw_isometric_net(c)
# Out:
# 300×366 Array{ARGB32,2} with eltype ColorTypes.ARGB32:
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
# ...

# %%
RubikView.draw_oblique_cube(c)
# Out:
# 174×174 Array{ARGB32,2} with eltype ColorTypes.ARGB32:
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
# ...

# %%
RubikView.draw_isometric_cube(c)
# Out:
# 210×186 Array{ARGB32,2} with eltype ColorTypes.ARGB32:
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)     ARGB32(0.0,0.0,0.0,0.0)
#  ARGB32(0.0,0.0,0.0,0.0)  ARGB32(0.0,0.0,0.0,0.0)  …  ARGB32(0.0,0.0,0.0,0.0)
# ...
